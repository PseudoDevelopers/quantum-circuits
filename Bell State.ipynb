# %%
from qiskit import QuantumCircuit
# %matplotlib inline

# %%
circuit = QuantumCircuit(2, 2)
circuit.h(0)
circuit.cx(0, 1)
circuit.measure([0, 1], [0, 1])

circuit.draw('mpl')

# %%
from load_account import loadAccount
loadAccount()
# Out:
# configrc.store_credentials:WARNING:2020-09-20 12:38:23,259: Credentials already present. Set overwrite=True to overwrite.
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
from qiskit import IBMQ
from qiskit.tools.monitor import job_monitor
from qiskit import execute

provider = IBMQ.get_provider('ibm-q')
backend = provider.get_backend('ibmq_qasm_simulator')

job = execute(circuit, backend=backend, shots=500)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
from qiskit.visualization import plot_histogram
from matplotlib import style
style.use('dark_background')

result = job.result()
counts = result.get_counts(circuit)
plot_histogram([counts])
